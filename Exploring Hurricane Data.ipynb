# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ships=pd.read_csv(r'C:\Users\kwonk\Guided Project\Hurricane_RMDS\Practice\Dataset_SHIPS_RII_ATL.csv')

# %%
ships.head(50)
# Out:
#     NAME    DATE  HOUR  VMX0   LAT   LON  MSLP        ID  DELV12  DELV24  ...  \
# 0   ALEX  980727    12    25  11.3 -25.4  1009  AL011998       0       5  ...
# 1   ALEX  980727    18    25  11.7 -27.2  1009  AL011998       0       5  ...
# 2   ALEX  980728     0    25  12.2 -29.2  1009  AL011998       5      10  ...
# 3   ALEX  980728     6    25  12.6 -31.3  1008  AL011998       5      10  ...
# 4   ALEX  980728    12    30  12.9 -33.3  1007  AL011998       5       5  ...
# 5   ALEX  980728    18    30  13.1 -35.1  1006  AL011998       5       5  ...
# 6   ALEX  980729     0    35  13.3 -36.8  1005  AL011998       0       0  ...
# 7   ALEX  980729     6    35  13.5 -38.5  1005  AL011998       0       5  ...
# 8   ALEX  980729    12    35  13.7 -40.0  1005  AL011998       0       5  ...
# 9   ALEX  980729    18    35  13.9 -41.3  1005  AL011998       5      10  ...
# 10  ALEX  980730     0    35  14.2 -42.6  1005  AL011998       5      10  ...
# ...

# %%
avg_speed = ships.groupby('ID').mean()
avg_speed = avg_speed.iloc[:5]
plt.bar(avg_speed.index,avg_speed['VMX0'],width=0.1)
avg_speed
# Out:
#                    DATE       HOUR       VMX0        LAT        LON  \
# ID
# AL011998  980751.461538   9.461538  35.384615  15.161538 -44.503846
# AL011999  990614.500000   9.000000  39.038462  30.069231 -60.242308
# AL012000     607.750000   9.000000  25.000000  20.850000 -93.100000
# AL012001   10611.240000   9.240000  25.700000  32.468000 -86.834000
# AL012002   20715.333333  10.000000  42.777778  37.466667 -67.066667
#
#                  MSLP       DELV12       DELV24       DELV36       DELV48  \
# ID
# AL011998  1007.000000   769.730769  1539.653846  2309.576923  3078.730769
# AL011999  1009.923077   768.961538  1537.923077  2305.923077  3074.500000
# AL012000  1009.250000  4999.500000  9999.000000  9999.000000  9999.000000
# AL012001  1005.740000   399.660000   799.220000  1199.380000  1599.540000
# AL012002  1002.444444  2226.444444  4450.666667  6672.111111  8890.222222
#
#           ...         PX30         SDBT         POT        OHC         TPW  \
# ID        ...
# ...
